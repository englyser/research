# %%
import numpy as np
from scipy.fftpack import fft, ifft
from scipy.signal import butter, lfilter
import scipy as sp
import matplotlib.pyplot as plt
from pylab import *


from time import perf_counter
import pandas as pd

# %matplotlib tk

# %%
l1 = 36.98494e-3;
l2 = 120.777e-3;
mcrank = 3.7191;
mrod = 283.35e-3;
I2 = 662523.4802e-9;
lg = 28.5827e-3;
mp = 417.63e-3;
engine_speed_rpm = 2000

# %%
theta = np.array(np.arange(0,720.1,0.1))

# %%
theta
# Out:
# array([0.000e+00, 1.000e-01, 2.000e-01, ..., 7.198e+02, 7.199e+02,
#        7.200e+02])

# %%
theta_d = engine_speed_rpm*2*np.pi/60
theta_d
# Out:
# 209.43951023931953

# %%
theta_dd = 0

# %%
beta = np.arcsin(l1*np.sin(theta)/l2)
beta
# Out:
# array([ 0.        ,  0.03057625,  0.06087511, ..., -0.11247928,
#        -0.14058802, -0.16738896])

# %%
beta_d(theta_t) = theta_d*l1*cos(theta)/l2/sqrt(1-
(l1*sin(theta)/l2)^2);

# %%
beta_d = (theta_d*l1*np.cos(theta))/(l2*np.sqrt(1-(np.square(l1*np.sin(theta)/l2))))

# %%
plt.plot(beta_d)
plt.xlim(0,100)
plt.show()

# %%
beta_dd= (l1*(theta_dd*np.cos(theta)-np.square(theta_d)*np.sin(theta_d))) + (np.square(theta_d)*np.power(l1,3)*np.square(np.cos(theta))*np.sin(theta))/(np.power(l2,3)*(1-(np.square(l1*np.sin(theta)/l2))))

# %%
plt.plot(beta_dd)
plt.xlim(0,100)
plt.show()
